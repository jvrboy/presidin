# %% [markdown]
# <a href="https://colab.research.google.com/github/jvrboy/everything-python/blob/main/notebooks/EVERYTHING_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ⚡ EVERYTHING — Python (Google Colab)
# Full app: AI chat (fleet failover) · live Signals (all forex + full Deriv synthetic suite) · real-time quotes · MIDI/Amapiano composer · logs.
#
# **Setup once:** open the 🔑 **Secrets** panel (left sidebar) and add: `SUPABASE_URL`, `SUPABASE_SERVICE_KEY`, `APP_PASSWORD`, `PROVIDER_FLEET_JSON`, `NGROK_AUTHTOKEN` (optional, for a public link).

# %%
# 1) Get the code (private repo — paste a GitHub token when prompted)
import os
if not os.path.exists('everything-python'):
    token = input('GitHub token (read access to jvrboy/everything-python): ')
    os.system(f'git clone -q https://jvrboy:{token}@github.com/jvrboy/everything-python.git')
# %cd everything-python
# Out:
# GitHub token (read access to jvrboy/everything-python): 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
# /content/everything-python

# %%
# 2) Install deps, load Colab secrets, start the app (prints local + public URLs)
import colab_setup
url = colab_setup.setup()
url
# Out:
# WARNING:everything.config:SESSION_SECRET not set — generated an EPHEMERAL secret (sessions reset on restart).
# WARNING:everything.config:APP_PASSWORD not set — legacy login disabled; use a migrated admin account.
# Exception in thread Thread-3 (run):
# Traceback (most recent call last):
#   File "/usr/lib/python3.13/threading.py", line 1044, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/threading.py", line 995, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/everything-python/colab_setup.py", line 35, in run
#     uvicorn.run(app, host="0.0.0.0", port=port, log_level="warning")
#     ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/uvicorn/main.py", line 579, in run
#     server.run()
#     ~~~~~~~~~~^^
#   File "/usr/local/lib/python3.13/dist-packages/uvicorn/server.py", line 65, in run
# ...

# %%
# 3) Smoke test
import httpx
print(httpx.get('http://127.0.0.1:8000/api/health', timeout=10).json())
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# /usr/local/lib/python3.13/dist-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#     100     try:
# --> 101         yield
#     102     except Exception as exc:
#
# /usr/local/lib/python3.13/dist-packages/httpx/_transports/default.py in handle_request(self, request)
#     249         with map_httpcore_exceptions():
# --> 250             resp = self._pool.handle_request(req)
#     251
#
# /usr/local/lib/python3.13/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     255             self._close_connections(closing)
# --> 256             raise exc from None
#     257
#
# /usr/local/lib/python3.13/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     235                     # Send the request on the assigned connection.
# ...
